# %%
# Import the dpeendencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citypy module to determine city based on lattitude and longitutde
from citipy import citipy

# %%
# Create a list for holiding cities. 
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 563

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c7e7e7214cac6abdccd968616b5eabe6

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
        
    # Parse out the needed data.
    try:
        city_country = city_weather["sys"]["country"]
    except:
        city_country = "not found"
        pass
    
    try:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
    except:
        print("City not found. Skipping...")
        pass
    
    try:
        city_max_temp = city_weather["main"]["temp_max"]
    except:
        city_max_temp = 0
        pass
    
    try:
        city_humidity = city_weather["main"]["humidity"]
    except:
        city_humidity = 0
        pass
    
    try:
        city_clouds = city_weather["clouds"]["all"]
    except:
        city_clouds = 0
        pass
    
    try:
        city_wind = city_weather["wind"]["speed"]
    except:
        city_wind = 0
        pass
    
    try:
        city_description = city_weather["weather"][0]["description"]
    except:
        city_description = "no weather description"
        pass
    
    try:
        city_rain = city_weather["rain"]["1h"]
    except:
        city_rain = 0
        pass
    
    try:
        city_snow = city_weather["snow"]["1h"]
    except:
        city_snow = 0
        pass 
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | virginia beach
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | senno
# Processing Record 10 of Set 1 | jalu
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | kiunga
# Processing Record 15 of Set 1 | sovetskiy
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | haines junction
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | aban
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | zarubino
# Processing Record 27 of Set 1 | hobyo
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | jiangkou
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | igarka
# Processing Record 32 of Set 1 | labrea
# Processing Record 33 of Set 1 | roald
# Processing Record 34 of Set 1 | nabire
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | bandar maharani
# City not found. Skipping...
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | senanga
# Processing Record 39 of Set 1 | paramirim
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | winnemucca
# Processing Record 42 of Set 1 | sidi ali
# Processing Record 43 of Set 1 | alto araguaia
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | tecpan
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | kalat
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | taoudenni
# Processing Record 3 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 2 | omboue
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | diffa
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | voloshka
# Processing Record 9 of Set 2 | tilik
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | ambilobe
# Processing Record 15 of Set 2 | eyl
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | taltal
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | san quintin
# Processing Record 22 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 2 | bushenyi
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | grand-lahou
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | suluq
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | berlevag
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | tazovskiy
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | aykhal
# Processing Record 42 of Set 2 | buon me thuot
# City not found. Skipping...
# Processing Record 43 of Set 2 | buala
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | deputatskiy
# Processing Record 47 of Set 2 | airai
# Processing Record 48 of Set 2 | spring valley
# Processing Record 49 of Set 2 | fort wellington
# Processing Record 50 of Set 2 | victor harbor
# Processing Record 1 of Set 3 | vaitape
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | yingcheng
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | kilindoni
# Processing Record 7 of Set 3 | los llanos de aridane
# Processing Record 8 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 9 of Set 3 | maryborough
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | kapaa
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | matara
# Processing Record 14 of Set 3 | swan river
# Processing Record 15 of Set 3 | firozpur jhirka
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | dali
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | xuanzhou
# Processing Record 21 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 3 | salalah
# Processing Record 23 of Set 3 | kachug
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | hovd
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 3 | svetlogorsk
# Processing Record 29 of Set 3 | pamekasan
# Processing Record 30 of Set 3 | petapa
# Processing Record 31 of Set 3 | dekar
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | mashhad
# Processing Record 36 of Set 3 | marawi
# Processing Record 37 of Set 3 | nishihara
# Processing Record 38 of Set 3 | parana
# Processing Record 39 of Set 3 | gayeri
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | linqiong
# Processing Record 42 of Set 3 | bonavista
# Processing Record 43 of Set 3 | aden
# Processing Record 44 of Set 3 | west plains
# Processing Record 45 of Set 3 | kopervik
# Processing Record 46 of Set 3 | zaysan
# Processing Record 47 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 3 | erattupetta
# Processing Record 49 of Set 3 | amahai
# Processing Record 50 of Set 3 | xining
# Processing Record 1 of Set 4 | ostrovnoy
# Processing Record 2 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 4 | riyadh
# Processing Record 4 of Set 4 | kudahuvadhoo
# Processing Record 5 of Set 4 | gojo
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | luanda
# Processing Record 10 of Set 4 | klyuchi
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | saint-augustin
# Processing Record 15 of Set 4 | jinchang
# Processing Record 16 of Set 4 | boulder city
# Processing Record 17 of Set 4 | port hedland
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 4 | oranjemund
# Processing Record 22 of Set 4 | wajima
# Processing Record 23 of Set 4 | de aar
# Processing Record 24 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | plouzane
# Processing Record 28 of Set 4 | narrabri
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | sokolo
# Processing Record 31 of Set 4 | vardo
# Processing Record 32 of Set 4 | canico
# Processing Record 33 of Set 4 | kurumkan
# Processing Record 34 of Set 4 | grindavik
# Processing Record 35 of Set 4 | saint-francois
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | tatui
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | xam nua
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | baruun-urt
# Processing Record 43 of Set 4 | turukhansk
# Processing Record 44 of Set 4 | green river
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | sorland
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | daoukro
# Processing Record 49 of Set 4 | sorong
# Processing Record 50 of Set 4 | yatou
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | marseille
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | pataskala
# Processing Record 8 of Set 5 | naze
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | obo
# Processing Record 11 of Set 5 | shilka
# Processing Record 12 of Set 5 | fuzhou
# Processing Record 13 of Set 5 | peleduy
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | bagdarin
# Processing Record 16 of Set 5 | lompoc
# Processing Record 17 of Set 5 | barrow
# Processing Record 18 of Set 5 | chaohu
# Processing Record 19 of Set 5 | adrar
# Processing Record 20 of Set 5 | henties bay
# Processing Record 21 of Set 5 | neryungri
# Processing Record 22 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 5 | tasiilaq
# Processing Record 24 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 5 | babushkin
# Processing Record 26 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | acapulco
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | bethanien
# Processing Record 31 of Set 5 | sigerfjord
# City not found. Skipping...
# Processing Record 32 of Set 5 | fort nelson
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 5 | ibanda
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | karratha
# Processing Record 43 of Set 5 | erzin
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | zhaotong
# Processing Record 46 of Set 5 | remerschen
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | jizan
# Processing Record 2 of Set 6 | chapais
# Processing Record 3 of Set 6 | sechura
# Processing Record 4 of Set 6 | monte cristi
# City not found. Skipping...
# Processing Record 5 of Set 6 | san luis
# Processing Record 6 of Set 6 | avera
# Processing Record 7 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 6 | bassar
# Processing Record 9 of Set 6 | praia
# Processing Record 10 of Set 6 | kushima
# Processing Record 11 of Set 6 | srednekolymsk
# Processing Record 12 of Set 6 | barra do garcas
# Processing Record 13 of Set 6 | port hardy
# Processing Record 14 of Set 6 | jonkoping
# Processing Record 15 of Set 6 | liuli
# Processing Record 16 of Set 6 | socastee
# Processing Record 17 of Set 6 | arteaga
# Processing Record 18 of Set 6 | sundsvall
# Processing Record 19 of Set 6 | arraial do cabo
# Processing Record 20 of Set 6 | hualmay
# Processing Record 21 of Set 6 | tacoronte
# Processing Record 22 of Set 6 | kasempa
# Processing Record 23 of Set 6 | ternate
# Processing Record 24 of Set 6 | saint-georges
# Processing Record 25 of Set 6 | fort-shevchenko
# Processing Record 26 of Set 6 | buchanan
# Processing Record 27 of Set 6 | puerto ayora
# Processing Record 28 of Set 6 | mazagao
# Processing Record 29 of Set 6 | marsh harbour
# Processing Record 30 of Set 6 | raudeberg
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | miri
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | calderitas
# Processing Record 35 of Set 6 | great falls
# Processing Record 36 of Set 6 | igrim
# Processing Record 37 of Set 6 | darhan
# Processing Record 38 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 6 | weligama
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | barao de melgaco
# Processing Record 42 of Set 6 | nynashamn
# Processing Record 43 of Set 6 | yatsushiro
# Processing Record 44 of Set 6 | sheltozero
# Processing Record 45 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | harpalpur
# Processing Record 49 of Set 6 | kalmunai
# Processing Record 50 of Set 6 | ray
# Processing Record 1 of Set 7 | rovaniemi
# Processing Record 2 of Set 7 | lensk
# Processing Record 3 of Set 7 | inuvik
# Processing Record 4 of Set 7 | panlaitan
# Processing Record 5 of Set 7 | merauke
# Processing Record 6 of Set 7 | ketchenery
# City not found. Skipping...
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | komagane
# Processing Record 9 of Set 7 | norheimsund
# Processing Record 10 of Set 7 | wyndham
# Processing Record 11 of Set 7 | rexburg
# Processing Record 12 of Set 7 | qaqortoq
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | soe
# Processing Record 15 of Set 7 | faanui
# Processing Record 16 of Set 7 | vizinga
# Processing Record 17 of Set 7 | la ronge
# Processing Record 18 of Set 7 | kaka
# Processing Record 19 of Set 7 | ambulu
# Processing Record 20 of Set 7 | baykit
# Processing Record 21 of Set 7 | rach gia
# Processing Record 22 of Set 7 | princeton
# Processing Record 23 of Set 7 | hare bay
# Processing Record 24 of Set 7 | kutum
# Processing Record 25 of Set 7 | marianske lazne
# Processing Record 26 of Set 7 | ibotirama
# Processing Record 27 of Set 7 | mumford
# Processing Record 28 of Set 7 | bakchar
# Processing Record 29 of Set 7 | steinbach
# Processing Record 30 of Set 7 | pedernales
# Processing Record 31 of Set 7 | sayyan
# Processing Record 32 of Set 7 | alenquer
# Processing Record 33 of Set 7 | atasu
# Processing Record 34 of Set 7 | risor
# Processing Record 35 of Set 7 | serov
# Processing Record 36 of Set 7 | balkanabat
# Processing Record 37 of Set 7 | jasper
# Processing Record 38 of Set 7 | elko
# Processing Record 39 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 7 | yeppoon
# Processing Record 41 of Set 7 | leshukonskoye
# Processing Record 42 of Set 7 | tilichiki
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | bria
# Processing Record 45 of Set 7 | milkovo
# Processing Record 46 of Set 7 | changzhou
# Processing Record 47 of Set 7 | cascais
# Processing Record 48 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 50 of Set 7 | nikolayevka
# Processing Record 1 of Set 8 | rio grande
# Processing Record 2 of Set 8 | krasnoselkup
# Processing Record 3 of Set 8 | russell
# Processing Record 4 of Set 8 | altay
# Processing Record 5 of Set 8 | anadyr
# Processing Record 6 of Set 8 | mmathubudukwane
# Processing Record 7 of Set 8 | savalou
# Processing Record 8 of Set 8 | buraydah
# Processing Record 9 of Set 8 | puerto madryn
# Processing Record 10 of Set 8 | klerksdorp
# Processing Record 11 of Set 8 | comodoro rivadavia
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | inhambane
# Processing Record 14 of Set 8 | malanje
# Processing Record 15 of Set 8 | yuty
# Processing Record 16 of Set 8 | tessalit
# Processing Record 17 of Set 8 | wuwei
# Processing Record 18 of Set 8 | grasse
# Processing Record 19 of Set 8 | semey
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | tigzirt
# Processing Record 22 of Set 8 | chicama
# Processing Record 23 of Set 8 | shirokiy
# Processing Record 24 of Set 8 | ussuriysk
# Processing Record 25 of Set 8 | jacareacanga
# Processing Record 26 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 8 | angoche
# Processing Record 28 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 8 | blagoyevo
# Processing Record 30 of Set 8 | evensk
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | kondoa
# Processing Record 33 of Set 8 | pizhanka
# Processing Record 34 of Set 8 | bukama
# Processing Record 35 of Set 8 | stokmarknes
# Processing Record 36 of Set 8 | ajdabiya
# Processing Record 37 of Set 8 | arona
# Processing Record 38 of Set 8 | iquique
# Processing Record 39 of Set 8 | mackay
# Processing Record 40 of Set 8 | fortuna
# Processing Record 41 of Set 8 | akureyri
# Processing Record 42 of Set 8 | palia kalan
# Processing Record 43 of Set 8 | sabang
# Processing Record 44 of Set 8 | champerico
# Processing Record 45 of Set 8 | tateyama
# Processing Record 46 of Set 8 | srivardhan
# Processing Record 47 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 8 | xuddur
# Processing Record 49 of Set 8 | bouna
# Processing Record 50 of Set 8 | khartoum
# Processing Record 1 of Set 9 | shumskiy
# Processing Record 2 of Set 9 | sandy bay
# Processing Record 3 of Set 9 | san policarpo
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | upernavik
# Processing Record 6 of Set 9 | rawson
# Processing Record 7 of Set 9 | bagnes
# Processing Record 8 of Set 9 | tomatlan
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 12 of Set 9 | severomorsk
# Processing Record 13 of Set 9 | saint-pierre
# Processing Record 14 of Set 9 | tuatapere
# Processing Record 15 of Set 9 | okha
# Processing Record 16 of Set 9 | gushikawa
# Processing Record 17 of Set 9 | yagodnoye
# Processing Record 18 of Set 9 | bathsheba
# Processing Record 19 of Set 9 | chitral
# Processing Record 20 of Set 9 | stornoway
# Processing Record 21 of Set 9 | gondar
# Processing Record 22 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 9 | loa janan
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | lorengau
# Processing Record 26 of Set 9 | camopi
# Processing Record 27 of Set 9 | madiun
# Processing Record 28 of Set 9 | kyra
# Processing Record 29 of Set 9 | port moresby
# Processing Record 30 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 9 | marzuq
# Processing Record 32 of Set 9 | te anau
# Processing Record 33 of Set 9 | trindade
# Processing Record 34 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 9 | cootamundra
# Processing Record 36 of Set 9 | alyangula
# Processing Record 37 of Set 9 | husavik
# Processing Record 38 of Set 9 | dingle
# Processing Record 39 of Set 9 | khor
# Processing Record 40 of Set 9 | nikita
# Processing Record 41 of Set 9 | lisala
# Processing Record 42 of Set 9 | hami
# Processing Record 43 of Set 9 | gat
# Processing Record 44 of Set 9 | nizhneangarsk
# Processing Record 45 of Set 9 | ilulissat
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | hannibal
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | sakaiminato
# Processing Record 1 of Set 10 | santa vitoria do palmar
# Processing Record 2 of Set 10 | ordu
# Processing Record 3 of Set 10 | ayagoz
# Processing Record 4 of Set 10 | kawalu
# Processing Record 5 of Set 10 | benalla
# Processing Record 6 of Set 10 | zalantun
# Processing Record 7 of Set 10 | avanigadda
# Processing Record 8 of Set 10 | maxixe
# Processing Record 9 of Set 10 | ginir
# Processing Record 10 of Set 10 | lodja
# Processing Record 11 of Set 10 | sooke
# Processing Record 12 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 10 | provideniya
# Processing Record 14 of Set 10 | rocha
# Processing Record 15 of Set 10 | margate
# Processing Record 16 of Set 10 | cairns
# Processing Record 17 of Set 10 | hofn
# Processing Record 18 of Set 10 | gawler
# Processing Record 19 of Set 10 | hanyang
# Processing Record 20 of Set 10 | yebaishou
# Processing Record 21 of Set 10 | bengkulu
# Processing Record 22 of Set 10 | ferkessedougou
# Processing Record 23 of Set 10 | tsumeb
# Processing Record 24 of Set 10 | benguela
# Processing Record 25 of Set 10 | khorramshahr
# Processing Record 26 of Set 10 | glenwood springs
# Processing Record 27 of Set 10 | greenville
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | quatre cocos
# Processing Record 31 of Set 10 | uyuni
# Processing Record 32 of Set 10 | halifax
# Processing Record 33 of Set 10 | lasa
# Processing Record 34 of Set 10 | harwich
# Processing Record 35 of Set 10 | irtyshskiy
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | koslan
# Processing Record 38 of Set 10 | caravelas
# Processing Record 39 of Set 10 | el pueblito
# Processing Record 40 of Set 10 | san bartolome de tirajana
# Processing Record 41 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | liepaja
# Processing Record 43 of Set 10 | waipawa
# Processing Record 44 of Set 10 | buin
# Processing Record 45 of Set 10 | fukue
# Processing Record 46 of Set 10 | egvekinot
# Processing Record 47 of Set 10 | agua branca
# Processing Record 48 of Set 10 | manakara
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 11 | sibu
# Processing Record 2 of Set 11 | souillac
# Processing Record 3 of Set 11 | biak
# Processing Record 4 of Set 11 | leningradskiy
# Processing Record 5 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 11 | zagare
# Processing Record 7 of Set 11 | katsuura
# Processing Record 8 of Set 11 | douentza
# Processing Record 9 of Set 11 | englewood
# Processing Record 10 of Set 11 | manadhoo
# Processing Record 11 of Set 11 | bairiki
# Processing Record 12 of Set 11 | tongliao
# Processing Record 13 of Set 11 | gra liyia
# Processing Record 14 of Set 11 | geraldton
# Processing Record 15 of Set 11 | marrakesh
# Processing Record 16 of Set 11 | north bend
# Processing Record 17 of Set 11 | tapiramuta
# Processing Record 18 of Set 11 | vao
# Processing Record 19 of Set 11 | beisfjord
# Processing Record 20 of Set 11 | guadalupe y calvo
# Processing Record 21 of Set 11 | nuuk
# Processing Record 22 of Set 11 | nyurba
# Processing Record 23 of Set 11 | krasnyy bogatyr
# Processing Record 24 of Set 11 | vestmannaeyjar
# Processing Record 25 of Set 11 | alice springs
# Processing Record 26 of Set 11 | bambanglipuro
# Processing Record 27 of Set 11 | whitehorse
# Processing Record 28 of Set 11 | jutai
# Processing Record 29 of Set 11 | pedini
# Processing Record 30 of Set 11 | paamiut
# Processing Record 31 of Set 11 | aripuana
# Processing Record 32 of Set 11 | sulphur springs
# Processing Record 33 of Set 11 | robertsport
# Processing Record 34 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 11 | wucheng
# Processing Record 36 of Set 11 | kindia
# Processing Record 37 of Set 11 | umaria
# Processing Record 38 of Set 11 | ploemeur
# Processing Record 39 of Set 11 | sosnovo-ozerskoye
# Processing Record 40 of Set 11 | gashua
# Processing Record 41 of Set 11 | capalna
# Processing Record 42 of Set 11 | visavadar
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | otjimbingwe
# Processing Record 45 of Set 11 | clinton
# Processing Record 46 of Set 11 | ust-uda
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | high rock
# Processing Record 49 of Set 11 | sfantu gheorghe
# Processing Record 50 of Set 11 | cockburn town
# Processing Record 1 of Set 12 | eregli
# Processing Record 2 of Set 12 | takoradi
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | nanga eboko
# Processing Record 5 of Set 12 | qandala
# Processing Record 6 of Set 12 | amapa
# Processing Record 7 of Set 12 | nelson bay
# Processing Record 8 of Set 12 | malatya
# Processing Record 9 of Set 12 | sinayawan
# Processing Record 10 of Set 12 | marshall
# Processing Record 11 of Set 12 | belaya gora
# Processing Record 12 of Set 12 | colac
# Processing Record 13 of Set 12 | maragogi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany         US  42.60  -73.97     72.00        69          51
# 1          Castro         BR -24.79  -50.01     49.96        69           0
# 2         Ushuaia         AR -54.80  -68.30     30.20        92          40
# 3  Virginia Beach         US  36.85  -75.98     82.00        78          40
# 4           Bluff         NZ -46.60  168.33     47.82        75           0
# 5       Taolanaro  not found -46.60  168.33      0.00         0           0
# 6       Mahebourg         MU -20.41   57.70     71.60        83          40
# 7          Atuona         PF  -9.80 -139.03     79.84        75           6
# 8           Senno         RU  59.53   33.92     51.84        74          99
# 9            Jalu         LY  29.03   21.55     76.44        50           0
#
#    Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 0        2.53                broken clouds            0.0              0
# 1        3.42                    clear sky            0.0              0
# 2        4.70             scattered clouds            0.0              0
# 3        5.82             scattered clouds            0.0              0
# 4       11.07                    clear sky            0.0              0
# 5        0.00       no weather description            0.0              0
# 6       12.75  light intensity shower rain            0.0              0
# 7       18.34                    clear sky            0.0              0
# 8        8.12              overcast clouds            0.0              0
# 9        8.25                    clear sky            0.0              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
